# %%
import os
import time

import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'HTBot.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from Database.models import Symbol, Candle

# %%
symbols = Symbol.objects.all()
len(symbols)
for symbol in symbols:
    print(symbol)
# Out:
# BTCUSDT
# ETHUSDT
# DOTUSDT
# BNBUSDT
# TRXUSDT
# DOGEUSDT

# %%
# # Symbol creations
# Symbol.objects.create(symbol="DOTUSDT")
# Symbol.objects.create(symbol="BNBUSDT")
# Symbol.objects.create(symbol="TRXUSDT")
# Symbol.objects.create(symbol="DOGEUSDT")
# Out:
# <Symbol: DOGEUSDT>

# %%
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from ExchangeAPI.APICallManager import CandleAgent, Interval

def process_candles(symbol, interval):
    agent = CandleAgent(symbol=symbol, interval=interval)
    for i in range(10):
        print(f"Processing {symbol} at {interval}, iteration {i}")
        candles = agent.fetch_past_candles(days=20)
        agent.save_to_db(candles)
        time.sleep(1)
    return f"Completed {symbol} at {interval}"

def main():
    symbols = Symbol.objects.all()
    intervals = [Interval.MIN_15, Interval.MIN_30, Interval.HOUR_1, Interval.HOUR_4]

    tasks = [(symbol.symbol, interval) for symbol in symbols for interval in intervals]

    max_workers = min(10, len(tasks))
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(process_candles, symbol, interval) for symbol, interval in tasks]

        for future in as_completed(futures):
            try:
                result = future.result()
                print(result)
            except Exception as e:
                print(f"Error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 162
# Processing ETHUSDT at Interval.MIN_15, iteration 0
# Processing BTCUSDT at Interval.HOUR_4, iteration 0
# Processing DOTUSDT at Interval.MIN_15, iteration 0
# Processing BTCUSDT at Interval.MIN_30, iteration 0
# Processing ETHUSDT at Interval.MIN_30, iteration 0
# Processing BTCUSDT at Interval.HOUR_1, iteration 0
# Processing BTCUSDT at Interval.MIN_15, iteration 0
# Processing ETHUSDT at Interval.HOUR_4, iteration 0
# Processing ETHUSDT at Interval.HOUR_1, iteration 0
# Processing DOTUSDT at Interval.MIN_30, iteration 0
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 1
# Processing BTCUSDT at Interval.HOUR_4, iteration 1
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 2
# Processing BTCUSDT at Interval.HOUR_4, iteration 2
# Request failed: 429 Client Error: Too Many Requests for url: https://api.bitget.com/api/v2/spot/market/history-candles?symbol=BTCUSDT&granularity=30min&endTime=1724776200000&limit=100
# Saved/updated 400 rows to candles table for BTCUSDT (interval: 1800000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Processing BTCUSDT at Interval.MIN_30, iteration 1
# Processing BTCUSDT at Interval.HOUR_1, iteration 1
# Processing ETHUSDT at Interval.HOUR_1, iteration 1
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 3
# Processing BTCUSDT at Interval.HOUR_4, iteration 3
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 4
# Processing BTCUSDT at Interval.HOUR_4, iteration 4
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Saved/updated 1000 rows to candles table for ETHUSDT (interval: 1800000ms).
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_1, iteration 2
# Saved/updated 1000 rows to candles table for DOTUSDT (interval: 1800000ms).
# Processing BTCUSDT at Interval.HOUR_1, iteration 2
# Processing ETHUSDT at Interval.MIN_30, iteration 1
# Processing ETHUSDT at Interval.HOUR_4, iteration 5
# Processing DOTUSDT at Interval.MIN_30, iteration 1
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing BTCUSDT at Interval.HOUR_4, iteration 5
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 6
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing BTCUSDT at Interval.HOUR_4, iteration 6
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 7
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing BTCUSDT at Interval.HOUR_4, iteration 7
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Saved/updated 1000 rows to candles table for BTCUSDT (interval: 1800000ms).
# Processing ETHUSDT at Interval.HOUR_1, iteration 3
# Processing BTCUSDT at Interval.HOUR_1, iteration 3
# Processing BTCUSDT at Interval.MIN_30, iteration 2
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.HOUR_4, iteration 8
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing BTCUSDT at Interval.HOUR_4, iteration 8
# Saved/updated 2000 rows to candles table for BTCUSDT (interval: 900000ms).
# Processing BTCUSDT at Interval.MIN_15, iteration 1
# Saved/updated 2000 rows to candles table for ETHUSDT (interval: 900000ms).
# Saved/updated 2000 rows to candles table for DOTUSDT (interval: 900000ms).
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Processing ETHUSDT at Interval.MIN_15, iteration 1
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.MIN_15, iteration 1
# Processing BTCUSDT at Interval.HOUR_4, iteration 9
# Processing ETHUSDT at Interval.HOUR_4, iteration 9
# Saved/updated 1000 rows to candles table for ETHUSDT (interval: 1800000ms).
# Saved/updated 1000 rows to candles table for DOTUSDT (interval: 1800000ms).
# Processing ETHUSDT at Interval.MIN_30, iteration 2
# Processing DOTUSDT at Interval.MIN_30, iteration 2
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Processing BTCUSDT at Interval.HOUR_1, iteration 4
# Processing ETHUSDT at Interval.HOUR_1, iteration 4
# Saved/updated 200 rows to candles table for BTCUSDT (interval: 14400000ms).
# Saved/updated 200 rows to candles table for ETHUSDT (interval: 14400000ms).
# Completed BTCUSDT at Interval.HOUR_4Processing DOTUSDT at Interval.HOUR_1, iteration 0
#
# Completed ETHUSDT at Interval.HOUR_4Processing DOTUSDT at Interval.HOUR_4, iteration 0
#
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 1
# Saved/updated 1000 rows to candles table for BTCUSDT (interval: 1800000ms).
# Processing BTCUSDT at Interval.MIN_30, iteration 3
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Processing ETHUSDT at Interval.HOUR_1, iteration 5
# Processing BTCUSDT at Interval.HOUR_1, iteration 5
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 2
# Saved/updated 500 rows to candles table for DOTUSDT (interval: 3600000ms).
# Processing DOTUSDT at Interval.HOUR_1, iteration 1
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 3
# Saved/updated 1000 rows to candles table for ETHUSDT (interval: 1800000ms).
# Saved/updated 1000 rows to candles table for DOTUSDT (interval: 1800000ms).
# Processing ETHUSDT at Interval.MIN_30, iteration 3
# Processing DOTUSDT at Interval.MIN_30, iteration 3
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 4
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Processing ETHUSDT at Interval.HOUR_1, iteration 6
# Processing BTCUSDT at Interval.HOUR_1, iteration 6
# Saved/updated 500 rows to candles table for DOTUSDT (interval: 3600000ms).
# Processing DOTUSDT at Interval.HOUR_1, iteration 2
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 5
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 6
# Saved/updated 1000 rows to candles table for BTCUSDT (interval: 1800000ms).
# Processing BTCUSDT at Interval.MIN_30, iteration 4
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Processing ETHUSDT at Interval.HOUR_1, iteration 7
# Processing BTCUSDT at Interval.HOUR_1, iteration 7
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 7
# Saved/updated 500 rows to candles table for DOTUSDT (interval: 3600000ms).
# Processing DOTUSDT at Interval.HOUR_1, iteration 3
# Saved/updated 2000 rows to candles table for BTCUSDT (interval: 900000ms).
# Processing BTCUSDT at Interval.MIN_15, iteration 2
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 8
# Saved/updated 2000 rows to candles table for ETHUSDT (interval: 900000ms).
# Saved/updated 2000 rows to candles table for DOTUSDT (interval: 900000ms).
# Processing ETHUSDT at Interval.MIN_15, iteration 2
# Processing DOTUSDT at Interval.MIN_15, iteration 2
# Saved/updated 1000 rows to candles table for DOTUSDT (interval: 1800000ms).
# Saved/updated 1000 rows to candles table for ETHUSDT (interval: 1800000ms).
# Processing DOTUSDT at Interval.MIN_30, iteration 4
# Processing ETHUSDT at Interval.MIN_30, iteration 4
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Processing DOTUSDT at Interval.HOUR_4, iteration 9
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Processing ETHUSDT at Interval.HOUR_1, iteration 8
# Processing BTCUSDT at Interval.HOUR_1, iteration 8
# Saved/updated 500 rows to candles table for DOTUSDT (interval: 3600000ms).
# Processing DOTUSDT at Interval.HOUR_1, iteration 4
# Saved/updated 200 rows to candles table for DOTUSDT (interval: 14400000ms).
# Completed DOTUSDT at Interval.HOUR_4Processing BNBUSDT at Interval.MIN_15, iteration 0
#
# Saved/updated 1000 rows to candles table for BTCUSDT (interval: 1800000ms).
# Processing BTCUSDT at Interval.MIN_30, iteration 5
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Processing BTCUSDT at Interval.HOUR_1, iteration 9
# Processing ETHUSDT at Interval.HOUR_1, iteration 9
# Saved/updated 500 rows to candles table for DOTUSDT (interval: 3600000ms).
# Processing DOTUSDT at Interval.HOUR_1, iteration 5
# Saved/updated 1000 rows to candles table for DOTUSDT (interval: 1800000ms).
# Saved/updated 1000 rows to candles table for ETHUSDT (interval: 1800000ms).
# Processing DOTUSDT at Interval.MIN_30, iteration 5
# Processing ETHUSDT at Interval.MIN_30, iteration 5
# Saved/updated 500 rows to candles table for BTCUSDT (interval: 3600000ms).
# Completed BTCUSDT at Interval.HOUR_1
# Processing BNBUSDT at Interval.MIN_30, iteration 0
# Request failed: 429 Client Error: Too Many Requests for url: https://api.bitget.com/api/v2/spot/market/history-candles?symbol=BNBUSDT&granularity=15min&endTime=1732067100000&limit=100
# Saved/updated 500 rows to candles table for ETHUSDT (interval: 3600000ms).
# Completed ETHUSDT at Interval.HOUR_1
# Processing BNBUSDT at Interval.HOUR_1, iteration 0
# Saved/updated 800 rows to candles table for BNBUSDT (interval: 900000ms).
# Saved/updated 500 rows to candles table for DOTUSDT (interval: 3600000ms).
# Processing BNBUSDT at Interval.MIN_15, iteration 1
# Processing DOTUSDT at Interval.HOUR_1, iteration 6
# Saved/updated 1000 rows to candles table for BTCUSDT (interval: 1800000ms).
# Processing BTCUSDT at Interval.MIN_30, iteration 6
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=BNBUSDT&granularity=1h&endTime=1720274400000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=BTCUSDT&granularity=15min&endTime=1705464000000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=ETHUSDT&granularity=30min&endTime=1700479800000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=DOTUSDT&granularity=30min&endTime=1724236200000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Saved/updated 400 rows to candles table for BNBUSDT (interval: 3600000ms).
# Processing BNBUSDT at Interval.HOUR_1, iteration 1
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=DOTUSDT&granularity=15min&endTime=1729367100000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=ETHUSDT&granularity=15min&endTime=1702366200000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Saved/updated 700 rows to candles table for ETHUSDT (interval: 1800000ms).
# Processing ETHUSDT at Interval.MIN_30, iteration 6
# Saved/updated 700 rows to candles table for DOTUSDT (interval: 1800000ms).
# Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=BNBUSDT&granularity=30min&endTime=1728016200000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))Request failed: HTTPSConnectionPool(host='api.bitget.com', port=443): Max retries exceeded with url: /api/v2/spot/market/history-candles?symbol=BNBUSDT&granularity=15min&endTime=1731707100000&limit=100 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
#
# Processing DOTUSDT at Interval.MIN_30, iteration 6
# Saved/updated 400 rows to candles table for BNBUSDT (interval: 900000ms).
# Saved/updated 1900 rows to candles table for BTCUSDT (interval: 900000ms).
# Saved/updated 600 rows to candles table for BNBUSDT (interval: 1800000ms).
# Processing BNBUSDT at Interval.MIN_15, iteration 2
# Processing BTCUSDT at Interval.MIN_15, iteration 3
# Processing BNBUSDT at Interval.MIN_30, iteration 1
# Saved/updated 1800 rows to candles table for DOTUSDT (interval: 900000ms).
# Saved/updated 1800 rows to candles table for ETHUSDT (interval: 900000ms).
# Processing DOTUSDT at Interval.MIN_15, iteration 3
# Processing ETHUSDT at Interval.MIN_15, iteration 3

# %%
8+Candle.objects.filter(symbol__symbol="TRXUSDT", interval=Interval.HOUR_4.value[1]).first().open_time
# Out:
# 1737907200000

# %%
def will_success(tp_percentage, sl_percentage, sign_candle: Candle, position_type: str):
    future_candles = Candle.objects.filter(
        symbol=sign_candle.symbol,
        interval=sign_candle.interval,
        open_time__gt=sign_candle.open_time
    )
    price = sign_candle.close
    if position_type == "long":
        tp_price = price * (1 + tp_percentage / 100)
        sl_price = price * (1 - sl_percentage / 100)
        for future_candle in future_candles:
            if future_candle.high >= tp_price:
                return True, future_candle.open_time
            elif future_candle.low <= sl_price:
                return False, future_candle.open_time
        return False, datetime.now().timestamp() * 1000
    else:
        sl_price = price * (1 + sl_percentage / 100)
        tp_price = price * (1 - tp_percentage / 100)
        for future_candle in future_candles:
            if future_candle.high >= sl_price:
                return False, future_candle.open_time
            elif future_candle.low <= tp_price:
                return True, future_candle.open_time
        return False, datetime.now().timestamp() * 1000

# %%
from django.db.models import QuerySet

# Strategy
def strategy(candles: QuerySet[Candle], tp_percentage: int, sl_percentage: int):
    total_counts = 0
    success_counts = 0
    last_time = candles.first().open_time
    for two_previous_candle, previous_candle, candle in zip(candles, candles[1:], candles[2:]):

        if candle.open_time <= last_time:
            continue

        if two_previous_candle.is_green() and previous_candle.is_green() and candle.is_green():
            total_counts += 1
            successful, last_time = will_success(
                tp_percentage=tp_percentage,
                sl_percentage=sl_percentage,
                sign_candle=candle,
                position_type="long",
            )
            if successful:
                success_counts += 1
                print("SUCCESS LONG")
                print(datetime.fromtimestamp(candle.open_time / 1000))
                print("**********************\n")
            else:
                print("FAIL LONG")
                print(datetime.fromtimestamp(candle.open_time / 1000))
                print("**********************\n")
        elif (not two_previous_candle.is_green() and
              not previous_candle.is_green() and
              not candle.is_green()):
            total_counts += 1
            successful, last_time = will_success(
                tp_percentage=tp_percentage,
                sl_percentage=sl_percentage,
                sign_candle=candle,
                position_type="short",
            )
            if successful:
                print("SHORT")
                print(datetime.fromtimestamp(candle.open_time / 1000))
                print("**********************\n")
                success_counts += 1
            else:
                print("FAIL SHORT")
                print(datetime.fromtimestamp(candle.open_time / 1000))
                print("**********************\n")

    return total_counts, success_counts

# %%
from datetime import datetime, timedelta
end_time = (datetime.now() - timedelta(days=0)).timestamp() * 1000
start_time = (datetime.now() - timedelta(days=30)).timestamp() * 1000

# %%
candles = Candle.objects.filter(symbol__symbol="TRXUSDT",
                                open_time__gte=start_time,
                                open_time__lte=end_time,
                                interval=Interval.HOUR_4.value[1])

# %%
print(candles.first().open_time)
print(candles.last().open_time)
# Out:
# 1752667200000
# 1755172800000

# %%
strategy(candles=candles, tp_percentage=5, sl_percentage=1)
# Out:
# SUCCESS LONG
# 2025-07-16 20:00:00
# **********************
#
# FAIL LONG
# 2025-07-18 04:00:00
# **********************
#
# SHORT
# 2025-07-20 12:00:00
# **********************
#
# FAIL LONG
# 2025-07-24 16:00:00
# **********************
#
# SUCCESS LONG
# 2025-07-25 20:00:00
# **********************
#
# FAIL SHORT
# 2025-07-30 12:00:00
# **********************
#
# FAIL SHORT
# 2025-07-31 20:00:00
# **********************
#
# FAIL SHORT
# 2025-08-01 20:00:00
# **********************
#
# FAIL SHORT
# 2025-08-02 16:00:00
# **********************
#
# SUCCESS LONG
# 2025-08-04 00:00:00
# **********************
#
# SUCCESS LONG
# 2025-08-11 20:00:00
# **********************
#
# FAIL LONG
# 2025-08-13 20:00:00
# **********************
# (12, 5)

# %%
from datetime import datetime, timedelta
first_parameter = 0
last_parameter = 30
tp_percentage = 10
sl_percentage=1
total_point = 0

while(last_parameter <= 210):
    end_time = (datetime.now() - timedelta(days=first_parameter)).timestamp() * 1000
    start_time = (datetime.now() - timedelta(days=last_parameter)).timestamp() * 1000
    candles = Candle.objects.filter(symbol__symbol="DOGEUSDT",
                                open_time__gte=start_time,
                                open_time__lte=end_time,
                                interval=Interval.HOUR_4.value[1])
    total, success = strategy(
        candles=candles,
        tp_percentage=tp_percentage,
        sl_percentage=sl_percentage,
    )

    print((total, success))

    fail = total - success
    total_point += (success * tp_percentage) - (fail * sl_percentage)
    first_parameter = last_parameter
    last_parameter += 30


print(total_point)
# Out:
# FAIL LONG
# 2025-07-16 20:00:00
# **********************
#
# FAIL LONG
# 2025-07-18 04:00:00
# **********************
#
# FAIL LONG
# 2025-07-19 04:00:00
# **********************
#
# FAIL LONG
# 2025-07-20 16:00:00
# **********************
#
# SHORT
# 2025-07-23 08:00:00
# **********************
#
# FAIL SHORT
# 2025-07-25 00:00:00
# **********************
#
# FAIL LONG
# 2025-07-27 20:00:00
# **********************
#
# SHORT
# 2025-07-28 12:00:00
# **********************
#
# FAIL LONG
# 2025-07-31 04:00:00
# **********************
#
# SHORT
# 2025-07-31 16:00:00
# **********************
#
# FAIL SHORT
# 2025-08-02 20:00:00
# **********************
#
# FAIL LONG
# 2025-08-03 08:00:00
# **********************
#
# FAIL LONG
# 2025-08-07 12:00:00
# **********************
#
# FAIL LONG
# 2025-08-07 20:00:00
# **********************
#
# FAIL LONG
# 2025-08-08 04:00:00
# **********************
#
# FAIL LONG
# 2025-08-09 12:00:00
# **********************
#
# FAIL LONG
# 2025-08-12 20:00:00
# **********************
#
# FAIL LONG
# 2025-08-13 04:00:00
# **********************
#
# FAIL LONG
# 2025-08-14 00:00:00
# **********************
#
# FAIL SHORT
# 2025-08-14 12:00:00
# **********************
#
# (20, 3)
# FAIL SHORT
# 2025-06-17 12:00:00
# **********************
#
# FAIL SHORT
# 2025-06-18 16:00:00
# **********************
#
# FAIL SHORT
# 2025-06-19 12:00:00
# **********************
#
# FAIL SHORT
# 2025-06-20 20:00:00
# **********************
#
# FAIL SHORT
# 2025-06-21 20:00:00
# **********************
#
# FAIL LONG
# 2025-06-23 00:00:00
# **********************
#
# FAIL LONG
# 2025-06-23 20:00:00
# **********************
#
# FAIL LONG
# 2025-06-24 12:00:00
# **********************
#
# FAIL SHORT
# 2025-06-26 12:00:00
# **********************
#
# FAIL LONG
# 2025-06-28 04:00:00
# **********************
#
# FAIL LONG
# 2025-06-28 20:00:00
# **********************
#
# FAIL SHORT
# 2025-07-01 08:00:00
# **********************
#
# FAIL LONG
# 2025-07-02 16:00:00
# **********************
#
# FAIL LONG
# 2025-07-05 04:00:00
# **********************
#
# FAIL LONG
# 2025-07-06 12:00:00
# **********************
#
# FAIL SHORT
# 2025-07-07 12:00:00
# **********************
#
# FAIL LONG
# 2025-07-11 00:00:00
# **********************
#
# FAIL LONG
# 2025-07-11 16:00:00
# **********************
#
# FAIL SHORT
# 2025-07-12 12:00:00
# **********************
#
# FAIL LONG
# 2025-07-13 00:00:00
# **********************
#
# FAIL SHORT
# 2025-07-14 16:00:00
# **********************
#
# (21, 0)
# FAIL LONG
# 2025-05-18 04:00:00
# **********************
#
# FAIL SHORT
# 2025-05-19 08:00:00
# **********************
#
# FAIL LONG
# 2025-05-19 20:00:00
# **********************
#
# FAIL SHORT
# 2025-05-20 12:00:00
# **********************
#
# FAIL LONG
# 2025-05-21 00:00:00
# **********************
#
# FAIL SHORT
# 2025-05-23 12:00:00
# **********************
#
# FAIL SHORT
# 2025-05-23 20:00:00
# **********************
#
# FAIL SHORT
# 2025-05-24 20:00:00
# **********************
#
# FAIL LONG
# 2025-05-26 04:00:00
# **********************
#
# SHORT
# 2025-05-27 20:00:00
# **********************
#
# SHORT
# 2025-05-30 04:00:00
# **********************
#
# FAIL SHORT
# 2025-06-05 20:00:00
# **********************
#
# FAIL LONG
# 2025-06-07 08:00:00
# **********************
#
# FAIL LONG
# 2025-06-08 16:00:00
# **********************
#
# FAIL SHORT
# 2025-06-09 04:00:00
# **********************
#
# SHORT
# 2025-06-12 00:00:00
# **********************
#
# FAIL LONG
# 2025-06-13 12:00:00
# **********************
#
# FAIL SHORT
# 2025-06-15 08:00:00
# **********************
#
# FAIL LONG
# 2025-06-16 04:00:00
# **********************
#
# (19, 3)
# FAIL LONG
# 2025-04-18 12:00:00
# **********************
#
# FAIL SHORT
# 2025-04-20 12:00:00
# **********************
#
# FAIL LONG
# 2025-04-21 00:00:00
# **********************
#
# SUCCESS LONG
# 2025-04-22 04:00:00
# **********************
#
# FAIL LONG
# 2025-04-23 04:00:00
# **********************
#
# FAIL LONG
# 2025-04-24 16:00:00
# **********************
#
# FAIL SHORT
# 2025-04-25 20:00:00
# **********************
#
# FAIL LONG
# 2025-04-29 00:00:00
# **********************
#
# FAIL LONG
# 2025-05-01 08:00:00
# **********************
#
# FAIL LONG
# 2025-05-01 16:00:00
# **********************
#
# FAIL SHORT
# 2025-05-03 08:00:00
# **********************
#
# SUCCESS LONG
# 2025-05-08 08:00:00
# **********************
#
# SUCCESS LONG
# 2025-05-10 00:00:00
# **********************
#
# FAIL LONG
# 2025-05-10 20:00:00
# **********************
#
# FAIL LONG
# 2025-05-12 00:00:00
# **********************
#
# FAIL SHORT
# 2025-05-12 16:00:00
# **********************
#
# FAIL LONG
# 2025-05-13 12:00:00
# **********************
#
# FAIL SHORT
# 2025-05-15 04:00:00
# **********************
#
# FAIL SHORT
# 2025-05-15 20:00:00
# **********************
#
# FAIL SHORT
# 2025-05-17 00:00:00
# **********************
#
# (20, 3)
# FAIL LONG
# 2025-03-19 00:00:00
# **********************
#
# FAIL SHORT
# 2025-03-21 08:00:00
# **********************
#
# SUCCESS LONG
# 2025-03-23 08:00:00
# **********************
#
# FAIL LONG
# 2025-03-25 12:00:00
# **********************
#
# SHORT
# 2025-03-27 12:00:00
# **********************
#
# FAIL SHORT
# 2025-03-29 12:00:00
# **********************
#
# FAIL SHORT
# 2025-03-30 12:00:00
# **********************
#
# FAIL SHORT
# 2025-03-31 04:00:00
# **********************
#
# FAIL LONG
# 2025-04-01 04:00:00
# **********************
#
# FAIL SHORT
# 2025-04-03 12:00:00
# **********************
#
# FAIL LONG
# 2025-04-04 00:00:00
# **********************
#
# FAIL LONG
# 2025-04-04 20:00:00
# **********************
#
# SHORT
# 2025-04-06 08:00:00
# **********************
#
# FAIL SHORT
# 2025-04-07 00:00:00
# **********************
#
# FAIL SHORT
# 2025-04-08 20:00:00
# **********************
#
# FAIL LONG
# 2025-04-09 20:00:00
# **********************
#
# FAIL LONG
# 2025-04-11 08:00:00
# **********************
#
# FAIL SHORT
# 2025-04-15 16:00:00
# **********************
#
# (18, 3)
# FAIL SHORT
# 2025-02-16 20:00:00
# **********************
#
# FAIL LONG
# 2025-02-19 00:00:00
# **********************
#
# FAIL LONG
# 2025-02-19 08:00:00
# **********************
#
# FAIL SHORT
# 2025-02-21 20:00:00
# **********************
#
# FAIL LONG
# 2025-02-22 08:00:00
# **********************
#
# FAIL SHORT
# 2025-02-24 16:00:00
# **********************
#
# FAIL SHORT
# 2025-02-25 00:00:00
# **********************
#
# FAIL LONG
# 2025-02-26 00:00:00
# **********************
#
# SHORT
# 2025-02-26 12:00:00
# **********************
#
# FAIL LONG
# 2025-02-28 16:00:00
# **********************
#
# FAIL LONG
# 2025-03-01 00:00:00
# **********************
#
# FAIL SHORT
# 2025-03-01 12:00:00
# **********************
#
# SUCCESS LONG
# 2025-03-02 12:00:00
# **********************
#
# FAIL LONG
# 2025-03-02 20:00:00
# **********************
#
# FAIL SHORT
# 2025-03-03 08:00:00
# **********************
#
# FAIL SHORT
# 2025-03-03 16:00:00
# **********************
#
# FAIL LONG
# 2025-03-05 08:00:00
# **********************
#
# FAIL LONG
# 2025-03-06 00:00:00
# **********************
#
# FAIL LONG
# 2025-03-07 12:00:00
# **********************
#
# SHORT
# 2025-03-08 04:00:00
# **********************
#
# FAIL SHORT
# 2025-03-09 16:00:00
# **********************
#
# FAIL LONG
# 2025-03-10 08:00:00
# **********************
#
# FAIL SHORT
# 2025-03-10 20:00:00
# **********************
#
# FAIL LONG
# 2025-03-11 08:00:00
# **********************
#
# (24, 3)
# FAIL SHORT
# 2025-01-18 04:00:00
# **********************
#
# FAIL SHORT
# 2025-01-18 20:00:00
# **********************
#
# FAIL LONG
# 2025-01-20 08:00:00
# **********************
#
# FAIL SHORT
# 2025-01-20 20:00:00
# **********************
#
# FAIL SHORT
# 2025-01-22 04:00:00
# **********************
#
# FAIL SHORT
# 2025-01-24 20:00:00
# **********************
#
# FAIL LONG
# 2025-01-25 16:00:00
# **********************
#
# SHORT
# 2025-01-26 12:00:00
# **********************
#
# FAIL SHORT
# 2025-01-27 08:00:00
# **********************
#
# FAIL SHORT
# 2025-01-28 12:00:00
# **********************
#
# FAIL SHORT
# 2025-01-31 00:00:00
# **********************
#
# FAIL LONG
# 2025-01-31 12:00:00
# **********************
#
# SHORT
# 2025-02-01 08:00:00
# **********************
#
# FAIL SHORT
# 2025-02-03 00:00:00
# **********************
#
# FAIL SHORT
# 2025-02-04 04:00:00
# **********************
#
# FAIL LONG
# 2025-02-05 08:00:00
# **********************
#
# FAIL SHORT
# 2025-02-05 20:00:00
# **********************
#
# FAIL SHORT
# 2025-02-06 16:00:00
# **********************
#
# FAIL SHORT
# 2025-02-07 20:00:00
# **********************
#
# FAIL LONG
# 2025-02-08 08:00:00
# **********************
#
# FAIL SHORT
# 2025-02-10 00:00:00
# **********************
#
# FAIL LONG
# 2025-02-10 12:00:00
# **********************
#
# FAIL LONG
# 2025-02-13 00:00:00
# **********************
#
# FAIL SHORT
# 2025-02-13 12:00:00
# **********************
#
# FAIL LONG
# 2025-02-14 04:00:00
# **********************
#
# (25, 2)
# 40

# %%
Candle.objects.filter(symbol__symbol="ETHUSDT", interval=Interval.MIN_15.value[1]).first().open_time
# Out:
# 1725586200000

# %%
len(candles)
# Out:
# 180

# %%
from Database.models import Candle, Symbol

# %%
newest_candle = Candle.objects.first()
oldest_candle = Candle.objects.last()

# %%
newest_candle.open_time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 newest_candle.open_time
#
# AttributeError: 'NoneType' object has no attribute 'open_time'

# %%
oldest_candle.open_time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 oldest_candle.open_time
#
# AttributeError: 'NoneType' object has no attribute 'open_time'

# %%
from ExchangeAPI.APICallManager import CandleAgent
from ExchangeAPI.APICallManager import Interval
agent = CandleAgent(symbol="BTCUSDT", interval=Interval.MIN_15)
candles = agent.fetch_future_candles()
agent.save_to_db(candles)
# Out:
# Saved/updated 100 rows to candles table for BTCUSDT (interval: 900000ms).
# 0

# %%
def check_candles_consistency(symbol_name: str, interval: Interval):
    candles = Candle.objects.filter(symbol__symbol=symbol_name, interval=interval.value[1])
    flag = True
    for previous_candle, candle in zip(candles, candles[1:]):
        if previous_candle.open_time + interval.value[1] != candle.open_time:
            flag = False
            print(previous_candle.open_time)
            break
    if flag:
        print("OKAY")

# %%
check_candles_consistency(symbol_name="TRXUSDT", interval=Interval.HOUR_4)
# Out:
# OKAY

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'HTBot.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
from Strategies.Indicators import RSI
from Database.models import Candle, Symbol
from ExchangeAPI.APICallManager import Interval
rsi = RSI(
    symbol=Symbol.objects.get(),
    interval=Interval.MIN_15.value[1],
    limit=10000,
)

data = rsi.calculate()

# %%
i = 0
for date, rsi in zip(data['open_time'], data['rsi']):
    i += 1
    print(f"{date} -> {rsi}")

print(i)
# Out:
# 1744201800000 -> nan
# 1744202700000 -> nan
# 1744203600000 -> nan
# 1744204500000 -> nan
# 1744205400000 -> nan
# 1744206300000 -> nan
# 1744207200000 -> nan
# 1744208100000 -> nan
# 1744209000000 -> nan
# 1744209900000 -> nan
# 1744210800000 -> nan
# 1744211700000 -> nan
# 1744212600000 -> nan
# 1744213500000 -> nan
# 1744214400000 -> 65.01668008184868
# 1744215300000 -> 62.1066326428812
# 1744216200000 -> 64.57764610310403
# 1744217100000 -> 68.24446423874465
# 1744218000000 -> 70.00039655748772
# 1744218900000 -> 81.38217758745252
# 1744219800000 -> 81.92779307287735
# 1744220700000 -> 85.29818827694076
# 1744221600000 -> 85.53680212064782
# 1744222500000 -> 86.1919738918066
# 1744223400000 -> 79.16692016270655
# 1744224300000 -> 75.36081840444862
# 1744225200000 -> 77.34414752411209
# 1744226100000 -> 77.8188949756199
# 1744227000000 -> 76.61489833776388
